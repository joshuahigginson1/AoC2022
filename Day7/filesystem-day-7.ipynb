# %%
# %pip install anytree
# Out:
# Requirement already satisfied: anytree in /Users/joshua.higginson/opt/anaconda3/envs/AdventofCode/lib/python3.10/site-packages (2.8.0)
# Requirement already satisfied: six>=1.9.0 in /Users/joshua.higginson/opt/anaconda3/envs/AdventofCode/lib/python3.10/site-packages (from anytree) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Data Structures

import anytree

class Node(anytree.NodeMixin):
    def __init__(self, node_name:str, node_type:str, node_path:str, node_size:int=0, length:int=1, width:int=1, parent=None, children=None):
    
        self.node_name = node_name
        self.node_type = node_type
        self.node_path = node_path
        self.node_size = node_size
        self.length = length
        self.width = width
        self.parent = parent
        
        # if children:
        #     self.children = children
            
    # https://blog.teclado.com/property-decorator-in-python/
    @property
    def node_size(self):
        if self.node_type == "file":
            return self._node_size
        else:
            return sum(child.node_size for child in self.children)
        
    @node_size.setter
    def node_size(self, new_node_size):
        self._node_size = new_node_size
               
    def __repr__(self):
        return f"{self.node_type.upper()}: {self.node_name} ({self.node_size} bytes)"

# %%
# Read our file input.

from pprint import pprint

with open("input.txt") as command_set:
    # Move pointer to start of file.
    command_set.seek(0)
    
    # Read all lines to a list without new line spacing.
    commands = command_set.read().splitlines()

# %%
def change_directory(command:str):
    """This method is used to virtually 'change directory', by appending and popping paths from a global list called 'DIRECTORY_POINTER_LIST.'

    Args:
        command (str): The directory to change to, or '..' to go back.
    """
    
    # If the command is to go back, we pop the last entry in our list.
    if command == "..":
        DIRECTORY_POINTER_LIST.pop()

    else:
        # Otherwise, we add it to our list.
        DIRECTORY_POINTER_LIST.append(command)

# %%
# Create a directory pointer list.
DIRECTORY_POINTER_LIST = []

# Create a root node and set it as index 0 to our nodes_list.
nodes_list = [Node("/", "dir", "/")]

for line in commands:
    if line.startswith('$ ls'):
        continue

    elif line.startswith('$ cd'):  # Deal with changing directories.
        # Change directory to the last substring in our string.
        change_directory(line.split()[-1])

    elif line.startswith('dir'):  # Deal with directory ls'es.
        dir_name = line.split()[-1]

        # Create a full path from our pointer list.
        base_path = "/".join(DIRECTORY_POINTER_LIST).replace("//", "/")
        dir_path = f"{base_path}/{dir_name}".replace("//", "/").replace("//", "/")

        # Pick parent with the same basepath as this current new node.
        parent = next((node for node in nodes_list if node.node_path == base_path), None)
        
        # Append it to our nodes_list.   
        nodes_list.append(Node(dir_name, "dir", dir_path, parent=parent))

    else:  # Deal with file ls'es.
        file_size, file_name = line.split()

        # Create a full path from our pointer list.
        base_path = "/".join(DIRECTORY_POINTER_LIST).replace("//", "/")
        file_path = f"{base_path}/{file_name}".replace("//", "/")

        # Pick parent with the same basepath as this current new node.
        parent = next((node for node in nodes_list if node.node_path == base_path), None)

        # Append it to our nodes_list.
        nodes_list.append(Node(file_name, "file", file_path, int(file_size), parent=parent))
        
print(anytree.RenderTree(nodes_list[0]))
# Out:
# DIR: / (46876531 bytes)
# ├── DIR: ccjp (1561333 bytes)
# │   ├── FILE: dlz (159990 bytes)
# │   ├── DIR: mbtsvblj (1236267 bytes)
# │   │   ├── FILE: frqsf.nsv (34806 bytes)
# │   │   ├── DIR: ppq (266252 bytes)
# │   │   │   └── FILE: dhzp (266252 bytes)
# │   │   ├── DIR: ptht (653838 bytes)
# │   │   │   ├── DIR: jbnj (395311 bytes)
# │   │   │   │   ├── DIR: clscr (249531 bytes)
# │   │   │   │   │   └── FILE: dhzp (249531 bytes)
# │   │   │   │   └── FILE: zwtwf.zfz (145780 bytes)
# │   │   │   └── DIR: zcbnwhzd (258527 bytes)
# │   │   │       └── DIR: mbtsvblj (258527 bytes)
# │   │   │           └── FILE: pjhvzjt.brz (258527 bytes)
# │   │   └── DIR: rgmvdwt (281371 bytes)
# │   │       ├── FILE: hdb (166021 bytes)
# │   │       └── FILE: ljpzpdbf (115350 bytes)
# │   └── FILE: nppbjl.qhg (165076 bytes)
# ├── FILE: hglnvs.bsh (328708 bytes)
# ├── DIR: hpsnpc (318283 bytes)
# │   ├── FILE: bfdfbrh.vff (6334 bytes)
# │   └── FILE: qphlw.whm (311949 bytes)
# ├── DIR: pcb (6258197 bytes)
# │   ├── DIR: ccjp (3698153 bytes)
# │   │   ├── FILE: ccjp (10932 bytes)
# │   │   ├── FILE: jjcggmr.ljs (80040 bytes)
# │   │   ├── FILE: jrqwhsn.ptv (299982 bytes)
# │   │   ├── FILE: ljpzpdbf (280655 bytes)
# │   │   ├── FILE: mdvvj.dlf (268430 bytes)
# │   │   ├── DIR: mvhhlg (146902 bytes)
# │   │   │   └── FILE: fwhcbfr.shd (146902 bytes)
# │   │   ├── DIR: ppfq (263452 bytes)
# │   │   │   └── FILE: hdb (263452 bytes)
# │   │   ├── DIR: rdgngdm (46355 bytes)
# │   │   │   └── FILE: wlgshdgl (46355 bytes)
# │   │   ├── DIR: smftmb (1318949 bytes)
# │   │   │   ├── FILE: mhs (56834 bytes)
# │   │   │   ├── FILE: ppmtvcj (325038 bytes)
# │   │   │   ├── DIR: rzcmwl (742432 bytes)
# │   │   │   │   ├── DIR: btfhswwf (62811 bytes)
# │   │   │   │   │   └── FILE: ccjp.clj (62811 bytes)
# │   │   │   │   ├── DIR: jrd (636444 bytes)
# │   │   │   │   │   ├── FILE: fqqg.pfc (184948 bytes)
# │   │   │   │   │   ├── DIR: mshf (314602 bytes)
# │   │   │   │   │   │   └── FILE: ppmtvcj (314602 bytes)
# │   │   │   │   │   └── FILE: nbvbr (136894 bytes)
# │   │   │   │   └── DIR: ndzfvl (43177 bytes)
# │   │   │   │       └── FILE: hhcfpnmg.njm (43177 bytes)
# │   │   │   └── FILE: ztwqq.jfw (194645 bytes)
# │   │   └── DIR: tqwchhd (982456 bytes)
# │   │       ├── FILE: dlz (294014 bytes)
# │   │       ├── FILE: ljpzpdbf (122061 bytes)
# │   │       ├── FILE: ppmtvcj.wlp (54178 bytes)
# │   │       ├── DIR: trm (279737 bytes)
# │   │       │   └── FILE: ccjp.mhz (279737 bytes)
# │   │       └── DIR: zcbnwhzd (232466 bytes)
# │   │           ├── FILE: dhnwjlzj (88477 bytes)
# │   │           └── FILE: dhzp (143989 bytes)
# │   ├── FILE: gbpzf.gmg (201615 bytes)
# │   ├── DIR: lhth (79532 bytes)
# │   │   └── FILE: tlls (79532 bytes)
# │   ├── FILE: lrmj.rmm (319302 bytes)
# │   ├── DIR: mwl (1656533 bytes)
# │   │   ├── DIR: frc (734512 bytes)
# │   │   │   ├── DIR: cvm (196619 bytes)
# │   │   │   │   └── FILE: hhcfpnmg.njm (196619 bytes)
# │   │   │   ├── FILE: dhzp (244013 bytes)
# │   │   │   ├── FILE: gnh (29325 bytes)
# │   │   │   └── FILE: hdb (264555 bytes)
# │   │   ├── DIR: lqqqppm (743445 bytes)
# │   │   │   ├── DIR: jdznl (704940 bytes)
# │   │   │   │   ├── FILE: ctt (85492 bytes)
# │   │   │   │   ├── FILE: dfbgtqj.vsb (228912 bytes)
# │   │   │   │   ├── FILE: nnwgd.vjn (136077 bytes)
# │   │   │   │   └── FILE: zrrzsfss (254459 bytes)
# │   │   │   └── FILE: nqv (38505 bytes)
# │   │   └── FILE: prpjmrw (178576 bytes)
# │   └── FILE: pvftq (303062 bytes)
# ├── DIR: pntzm (29757629 bytes)
# │   ├── DIR: hnnhdd (365617 bytes)
# │   │   ├── FILE: fjp (35908 bytes)
# │   │   ├── FILE: ljpzpdbf (119221 bytes)
# │   │   └── FILE: whhpztz.lgt (210488 bytes)
# │   ├── DIR: mbtsvblj (27924493 bytes)
# │   │   ├── DIR: clfpc (3817518 bytes)
# │   │   │   ├── DIR: jffq (219280 bytes)
# │   │   │   │   ├── DIR: dpngpgr (128899 bytes)
# │   │   │   │   │   └── FILE: ccjp.nbs (128899 bytes)
# │   │   │   │   └── DIR: htbf (90381 bytes)
# │   │   │   │       └── FILE: ljpzpdbf (90381 bytes)
# │   │   │   ├── DIR: qpsfrhld (3508669 bytes)
# │   │   │   │   ├── DIR: bgrb (314458 bytes)
# │   │   │   │   │   ├── FILE: ccjp.zmf (119046 bytes)
# │   │   │   │   │   └── DIR: qsnng (195412 bytes)
# │   │   │   │   │       └── FILE: vjdh.cqv (195412 bytes)
# │   │   │   │   ├── DIR: ddtlcfz (1792584 bytes)
# │   │   │   │   │   ├── DIR: ftfch (766912 bytes)
# │   │   │   │   │   │   ├── FILE: dhzp (50242 bytes)
# │   │   │   │   │   │   ├── FILE: dlz (58846 bytes)
# │   │   │   │   │   │   └── DIR: hhwsrzhv (657824 bytes)
# │   │   │   │   │   │       ├── DIR: bjnn (199806 bytes)
# │   │   │   │   │   │       │   └── FILE: dlz (199806 bytes)
# │   │   │   │   │   │       ├── FILE: dhzp (67610 bytes)
# │   │   │   │   │   │       ├── DIR: mbtsvblj (184744 bytes)
# │   │   │   │   │   │       │   └── DIR: ffzjcshp (184744 bytes)
# │   │   │   │   │   │       │       └── DIR: ppmtvcj (184744 bytes)
# │   │   │   │   │   │       │           └── FILE: dlz (184744 bytes)
# │   │   │   │   │   │       └── FILE: tmcfmshb (205664 bytes)
# │   │   │   │   │   ├── FILE: mbtsvblj (26717 bytes)
# │   │   │   │   │   ├── FILE: mbtsvblj.rfb (157679 bytes)
# │   │   │   │   │   ├── FILE: qmg (299928 bytes)
# │   │   │   │   │   ├── DIR: trq (278471 bytes)
# │   │   │   │   │   │   └── FILE: ccjp (278471 bytes)
# │   │   │   │   │   └── DIR: wjhjlpr (262877 bytes)
# │   │   │   │   │       └── DIR: wzwqrfhv (262877 bytes)
# │   │   │   │   │           └── FILE: ccjp (262877 bytes)
# │   │   │   │   ├── FILE: dlz (54115 bytes)
# │   │   │   │   ├── FILE: hhcfpnmg.njm (154299 bytes)
# │   │   │   │   ├── FILE: jwc.pwg (59452 bytes)
# │   │   │   │   └── DIR: mbtsvblj (1133761 bytes)
# │   │   │   │       ├── FILE: ccjp.szb (243142 bytes)
# │   │   │   │       ├── FILE: lmstdpfc.nww (306673 bytes)
# │   │   │   │       ├── DIR: nlsprnh (200708 bytes)
# │   │   │   │       │   └── FILE: stbjphg.hcs (200708 bytes)
# │   │   │   │       ├── DIR: nmzwtwwc (323366 bytes)
# │   │   │   │       │   └── FILE: vzq.pcj (323366 bytes)
# │   │   │   │       └── DIR: rbpbl (59872 bytes)
# │   │   │   │           └── FILE: fmnmsjr.svf (59872 bytes)
# │   │   │   └── FILE: tdzfqpz.wvs (89569 bytes)
# │   │   ├── DIR: csqcnmtc (9405481 bytes)
# │   │   │   ├── FILE: ccjp (16652 bytes)
# │   │   │   ├── DIR: fsfd (105721 bytes)
# │   │   │   │   └── FILE: qqvchq.mwh (105721 bytes)
# │   │   │   ├── FILE: hdb (37144 bytes)
# │   │   │   ├── DIR: mbtsvblj (7991939 bytes)
# │   │   │   │   ├── DIR: cdzgtll (487538 bytes)
# │   │   │   │   │   ├── FILE: dhzp (163523 bytes)
# │   │   │   │   │   ├── FILE: dlz (124219 bytes)
# │   │   │   │   │   └── FILE: hdb (199796 bytes)
# │   │   │   │   ├── DIR: dfgd (3401443 bytes)
# │   │   │   │   │   ├── FILE: ccjp.cbt (173064 bytes)
# │   │   │   │   │   ├── DIR: cdqc (178924 bytes)
# │   │   │   │   │   │   └── FILE: hdb (178924 bytes)
# │   │   │   │   │   ├── DIR: fzrm (1463474 bytes)
# │   │   │   │   │   │   ├── DIR: bjwtbc (325981 bytes)
# │   │   │   │   │   │   │   ├── FILE: hhcfpnmg.njm (9891 bytes)
# │   │   │   │   │   │   │   └── DIR: mwl (316090 bytes)
# │   │   │   │   │   │   │       ├── FILE: glwp.dls (203337 bytes)
# │   │   │   │   │   │   │       └── FILE: mwl.qph (112753 bytes)
# │   │   │   │   │   │   ├── FILE: dhzp (211229 bytes)
# │   │   │   │   │   │   ├── DIR: dtslj (277817 bytes)
# │   │   │   │   │   │   │   └── FILE: hhcfpnmg.njm (277817 bytes)
# │   │   │   │   │   │   ├── FILE: mbtsvblj.mtw (76461 bytes)
# │   │   │   │   │   │   ├── FILE: mmz.mqq (317618 bytes)
# │   │   │   │   │   │   ├── DIR: mwl (90781 bytes)
# │   │   │   │   │   │   │   └── FILE: mhnrwpmg.svv (90781 bytes)
# │   │   │   │   │   │   └── FILE: vwgq (163587 bytes)
# │   │   │   │   │   ├── DIR: grcs (286144 bytes)
# │   │   │   │   │   │   └── FILE: rnfqhs (286144 bytes)
# │   │   │   │   │   ├── FILE: mbtsvblj.zrl (87000 bytes)
# │   │   │   │   │   ├── DIR: njvgs (509319 bytes)
# │   │   │   │   │   │   ├── DIR: bmhdth (154455 bytes)
# │   │   │   │   │   │   │   └── FILE: ppmtvcj.hwq (154455 bytes)
# │   │   │   │   │   │   ├── DIR: ccjp (215864 bytes)
# │   │   │   │   │   │   │   └── FILE: fcwjtzhs.vqn (215864 bytes)
# │   │   │   │   │   │   └── DIR: mwl (139000 bytes)
# │   │   │   │   │   │       └── FILE: fnjztz (139000 bytes)
# │   │   │   │   │   ├── DIR: ppmtvcj (79812 bytes)
# │   │   │   │   │   │   ├── FILE: jzfnmdw.jms (45041 bytes)
# │   │   │   │   │   │   └── DIR: zstzfs (34771 bytes)
# │   │   │   │   │   │       └── DIR: qsfsj (34771 bytes)
# │   │   │   │   │   │           └── FILE: rsv (34771 bytes)
# │   │   │   │   │   ├── FILE: rhtslcwt.wgt (210984 bytes)
# │   │   │   │   │   └── DIR: vws (412722 bytes)
# │   │   │   │   │       ├── FILE: pjs (98036 bytes)
# │   │   │   │   │       ├── FILE: szszjfv (103603 bytes)
# │   │   │   │   │       └── FILE: ztd (211083 bytes)
# │   │   │   │   ├── DIR: fbfr (2628522 bytes)
# │   │   │   │   │   ├── DIR: dshrpf (796168 bytes)
# │   │   │   │   │   │   ├── DIR: nll (560898 bytes)
# │   │   │   │   │   │   │   ├── FILE: flmvswv.rll (45935 bytes)
# │   │   │   │   │   │   │   ├── FILE: hhcfpnmg.njm (4161 bytes)
# │   │   │   │   │   │   │   ├── FILE: sww.dwj (82301 bytes)
# │   │   │   │   │   │   │   ├── DIR: tqdmtp (280430 bytes)
# │   │   │   │   │   │   │   │   └── FILE: dhzp (280430 bytes)
# │   │   │   │   │   │   │   ├── FILE: tzrn.qrt (46608 bytes)
# │   │   │   │   │   │   │   └── FILE: zcbnwhzd.mpm (101463 bytes)
# │   │   │   │   │   │   └── DIR: qrsg (235270 bytes)
# │   │   │   │   │   │       └── DIR: htrvnvz (235270 bytes)
# │   │   │   │   │   │           └── DIR: mbtsvblj (235270 bytes)
# │   │   │   │   │   │               └── FILE: dlz (235270 bytes)
# │   │   │   │   │   ├── FILE: hbw.jhj (216109 bytes)
# │   │   │   │   │   ├── FILE: hdhl (319355 bytes)
# │   │   │   │   │   ├── DIR: ltf (469871 bytes)
# │   │   │   │   │   │   ├── DIR: pcbc (140010 bytes)
# │   │   │   │   │   │   │   └── FILE: mbtsvblj.hqd (140010 bytes)
# │   │   │   │   │   │   ├── DIR: wwjnwbjj (27497 bytes)
# │   │   │   │   │   │   │   └── DIR: mwl (27497 bytes)
# │   │   │   │   │   │   │       └── DIR: pddbdp (27497 bytes)
# │   │   │   │   │   │   │           └── FILE: dlz (27497 bytes)
# │   │   │   │   │   │   └── DIR: zcbnwhzd (302364 bytes)
# │   │   │   │   │   │       └── FILE: nrgpwm.cbb (302364 bytes)
# │   │   │   │   │   ├── FILE: qstlgvb (210950 bytes)
# │   │   │   │   │   ├── DIR: thhncv (299769 bytes)
# │   │   │   │   │   │   └── FILE: hdb (299769 bytes)
# │   │   │   │   │   └── FILE: zfgh (316300 bytes)
# │   │   │   │   ├── FILE: mbtsvblj (165975 bytes)
# │   │   │   │   ├── FILE: ppmtvcj (174541 bytes)
# │   │   │   │   └── DIR: vwgrpswj (1133920 bytes)
# │   │   │   │       ├── DIR: jgt (282773 bytes)
# │   │   │   │       │   └── FILE: hhcfpnmg.njm (282773 bytes)
# │   │   │   │       ├── DIR: mwl (557474 bytes)
# │   │   │   │       │   ├── FILE: jfnjdtr.ssj (288944 bytes)
# │   │   │   │       │   ├── FILE: wfr (186368 bytes)
# │   │   │   │       │   └── DIR: zrtvvf (82162 bytes)
# │   │   │   │       │       └── FILE: gtz.gsc (82162 bytes)
# │   │   │   │       └── FILE: mwl.pwl (293673 bytes)
# │   │   │   ├── DIR: mwl (641081 bytes)
# │   │   │   │   ├── FILE: htc.qjr (98218 bytes)
# │   │   │   │   ├── DIR: mghhqrtn (256676 bytes)
# │   │   │   │   │   ├── FILE: dlz (220446 bytes)
# │   │   │   │   │   └── FILE: pwwlwv.crn (36230 bytes)
# │   │   │   │   └── DIR: qct (286187 bytes)
# │   │   │   │       ├── FILE: hdb (33534 bytes)
# │   │   │   │       ├── FILE: jpwqvbs.mvr (27140 bytes)
# │   │   │   │       ├── FILE: mlqtp (60637 bytes)
# │   │   │   │       ├── FILE: nlvtp.qjn (12143 bytes)
# │   │   │   │       └── FILE: nqjqzt (152733 bytes)
# │   │   │   ├── FILE: nljlpbjq (66387 bytes)
# │   │   │   ├── DIR: ppmtvcj (425718 bytes)
# │   │   │   │   ├── DIR: ccjp (128473 bytes)
# │   │   │   │   │   └── FILE: wcw.dng (128473 bytes)
# │   │   │   │   └── FILE: zcbnwhzd (297245 bytes)
# │   │   │   └── FILE: rgclgwnq (120839 bytes)
# │   │   ├── FILE: mbtsvblj (18524 bytes)
# │   │   └── DIR: zcrrtlh (14682970 bytes)
# │   │       ├── FILE: bcbnmhq (27488 bytes)
# │   │       ├── DIR: dhsmmlt (13246500 bytes)
# │   │       │   ├── FILE: cvfwqnfl (42514 bytes)
# │   │       │   ├── FILE: dlz (252570 bytes)
# │   │       │   ├── FILE: ppmtvcj.snb (145814 bytes)
# │   │       │   ├── FILE: rslsh.slv (294613 bytes)
# │   │       │   ├── FILE: vwd.spz (186477 bytes)
# │   │       │   └── DIR: wffbp (12324512 bytes)
# │   │       │       ├── DIR: mbtsvblj (10264814 bytes)
# │   │       │       │   ├── FILE: cmmlw.bmq (65132 bytes)
# │   │       │       │   ├── FILE: cqrtmpdp.pjq (310866 bytes)
# │   │       │       │   ├── DIR: mbtsvblj (8113815 bytes)
# │   │       │       │   │   ├── DIR: bzpdz (704374 bytes)
# │   │       │       │   │   │   ├── FILE: gtmftv (272769 bytes)
# │   │       │       │   │   │   ├── FILE: hhcfpnmg.njm (280597 bytes)
# │   │       │       │   │   │   └── FILE: nmgvrhr.mvp (151008 bytes)
# │   │       │       │   │   ├── DIR: mbtsvblj (3352420 bytes)
# │   │       │       │   │   │   ├── FILE: czn (64862 bytes)
# │   │       │       │   │   │   ├── FILE: dhzp (309781 bytes)
# │   │       │       │   │   │   ├── FILE: dlz (253325 bytes)
# │   │       │       │   │   │   ├── DIR: dqnr (642242 bytes)
# │   │       │       │   │   │   │   ├── FILE: cjnwm.lrb (302986 bytes)
# │   │       │       │   │   │   │   ├── FILE: frhjlp.rnn (158871 bytes)
# │   │       │       │   │   │   │   └── FILE: nrlmq (180385 bytes)
# │   │       │       │   │   │   ├── DIR: fgd (158213 bytes)
# │   │       │       │   │   │   │   └── FILE: msjrcl.dsh (158213 bytes)
# │   │       │       │   │   │   ├── FILE: ghtzv (139779 bytes)
# │   │       │       │   │   │   ├── FILE: rml.rhm (255567 bytes)
# │   │       │       │   │   │   └── DIR: srfzjfw (1528651 bytes)
# │   │       │       │   │   │       ├── DIR: jfnd (300883 bytes)
# │   │       │       │   │   │       │   └── FILE: zvtdj.srv (300883 bytes)
# │   │       │       │   │   │       ├── FILE: ljpzpdbf (210830 bytes)
# │   │       │       │   │   │       ├── DIR: mbtsvblj (600295 bytes)
# │   │       │       │   │   │       │   ├── FILE: cjdm.whc (287467 bytes)
# │   │       │       │   │   │       │   ├── FILE: hpfgtnts (233084 bytes)
# │   │       │       │   │   │       │   └── DIR: zcbnwhzd (79744 bytes)
# │   │       │       │   │   │       │       └── FILE: dlz (79744 bytes)
# │   │       │       │   │   │       └── DIR: zcrrvpg (416643 bytes)
# │   │       │       │   │   │           ├── DIR: jrbcqlct (325945 bytes)
# │   │       │       │   │   │           │   └── FILE: dlz (325945 bytes)
# │   │       │       │   │   │           └── DIR: srpm (90698 bytes)
# │   │       │       │   │   │               └── FILE: ngw.fhm (90698 bytes)
# │   │       │       │   │   ├── DIR: pwnn (104826 bytes)
# │   │       │       │   │   │   └── FILE: ppmtvcj.jtm (104826 bytes)
# │   │       │       │   │   └── DIR: zcbnwhzd (3952195 bytes)
# │   │       │       │   │       ├── FILE: fnr.dgt (145508 bytes)
# │   │       │       │   │       ├── FILE: gwdl.vfl (256683 bytes)
# │   │       │       │   │       ├── DIR: mdv (3156368 bytes)
# │   │       │       │   │       │   ├── FILE: dlz (231290 bytes)
# │   │       │       │   │       │   ├── FILE: hdb (3468 bytes)
# │   │       │       │   │       │   ├── FILE: mcm (95091 bytes)
# │   │       │       │   │       │   ├── FILE: mwl.ncb (67779 bytes)
# │   │       │       │   │       │   ├── DIR: ppf (73809 bytes)
# │   │       │       │   │       │   │   └── FILE: rgdtlp (73809 bytes)
# │   │       │       │   │       │   ├── DIR: rfwwtjdn (799190 bytes)
# │   │       │       │   │       │   │   ├── FILE: dhzp (255306 bytes)
# │   │       │       │   │       │   │   ├── FILE: zbnmtcgr.ddf (306865 bytes)
# │   │       │       │   │       │   │   └── FILE: zcbnwhzd.szn (237019 bytes)
# │   │       │       │   │       │   ├── FILE: slrv.qdl (143730 bytes)
# │   │       │       │   │       │   └── DIR: sqbdvppf (1742011 bytes)
# │   │       │       │   │       │       ├── DIR: ccjp (325451 bytes)
# │   │       │       │   │       │       │   ├── FILE: cwtvtcnp.tft (29914 bytes)
# │   │       │       │   │       │       │   └── FILE: rvlb (295537 bytes)
# │   │       │       │   │       │       ├── DIR: mbtsvblj (809510 bytes)
# │   │       │       │   │       │       │   ├── FILE: ccjp.wbn (262652 bytes)
# │   │       │       │   │       │       │   ├── FILE: mbtsvblj.gnz (297839 bytes)
# │   │       │       │   │       │       │   └── FILE: pqsqjg.vwr (249019 bytes)
# │   │       │       │   │       │       ├── FILE: str (142955 bytes)
# │   │       │       │   │       │       ├── DIR: whtrbcqn (370688 bytes)
# │   │       │       │   │       │       │   ├── DIR: ccjp (39489 bytes)
# │   │       │       │   │       │       │   │   └── FILE: slps (39489 bytes)
# │   │       │       │   │       │       │   ├── DIR: hslmvvb (280159 bytes)
# │   │       │       │   │       │       │   │   ├── FILE: gpwnf.qtd (148628 bytes)
# │   │       │       │   │       │       │   │   ├── DIR: jrl (119717 bytes)
# │   │       │       │   │       │       │   │   │   └── DIR: scwlmjzm (119717 bytes)
# │   │       │       │   │       │       │   │   │       └── FILE: vhpsrbzw.jnh (119717 bytes)
# │   │       │       │   │       │       │   │   └── FILE: qtjtsvgg.ltz (11814 bytes)
# │   │       │       │   │       │       │   └── FILE: vzcsfcwf (51040 bytes)
# │   │       │       │   │       │       └── FILE: zcbnwhzd.ctr (93407 bytes)
# │   │       │       │   │       ├── FILE: mqdv.cdb (44255 bytes)
# │   │       │       │   │       ├── FILE: rgvcf (79723 bytes)
# │   │       │       │   │       ├── DIR: sjdh (43495 bytes)
# │   │       │       │   │       │   └── FILE: srwzspsl (43495 bytes)
# │   │       │       │   │       ├── FILE: wdgq.hfm (88945 bytes)
# │   │       │       │   │       └── DIR: zpm (137218 bytes)
# │   │       │       │   │           └── FILE: mwl.pzt (137218 bytes)
# │   │       │       │   ├── FILE: mbtsvblj.spw (212527 bytes)
# │   │       │       │   ├── FILE: ngmltt.qwl (232198 bytes)
# │   │       │       │   ├── DIR: pbqh (405568 bytes)
# │   │       │       │   │   ├── FILE: dlz (202610 bytes)
# │   │       │       │   │   └── DIR: vdrqc (202958 bytes)
# │   │       │       │   │       └── FILE: mzzmjrt (202958 bytes)
# │   │       │       │   ├── DIR: ppwgsp (248541 bytes)
# │   │       │       │   │   └── FILE: pzvtdl.lcc (248541 bytes)
# │   │       │       │   ├── DIR: qqfsb (452845 bytes)
# │   │       │       │   │   ├── FILE: mbtsvblj.fvh (211390 bytes)
# │   │       │       │   │   └── FILE: mwl.bzl (241455 bytes)
# │   │       │       │   └── FILE: tzsmvh (223322 bytes)
# │   │       │       ├── DIR: nvq (340703 bytes)
# │   │       │       │   ├── FILE: hhcfpnmg.njm (74730 bytes)
# │   │       │       │   ├── FILE: ljpzpdbf (257109 bytes)
# │   │       │       │   └── FILE: zcbnwhzd.ctj (8864 bytes)
# │   │       │       ├── FILE: ppmtvcj.hzc (150447 bytes)
# │   │       │       ├── FILE: whzpsbqp.clq (34904 bytes)
# │   │       │       └── DIR: zcbnwhzd (1533644 bytes)
# │   │       │           ├── FILE: ccjp (307501 bytes)
# │   │       │           ├── DIR: dfgbztqr (546961 bytes)
# │   │       │           │   ├── FILE: hdb (18261 bytes)
# │   │       │           │   ├── DIR: mwl (319891 bytes)
# │   │       │           │   │   ├── FILE: hdv.vfs (36787 bytes)
# │   │       │           │   │   └── FILE: zrvbsht.fmm (283104 bytes)
# │   │       │           │   └── DIR: ppmtvcj (208809 bytes)
# │   │       │           │       └── FILE: ljpzpdbf (208809 bytes)
# │   │       │           ├── DIR: mwl (420480 bytes)
# │   │       │           │   ├── FILE: mgfvgw (195369 bytes)
# │   │       │           │   ├── FILE: mwl (146522 bytes)
# │   │       │           │   └── FILE: sfthn (78589 bytes)
# │   │       │           ├── FILE: pmhtz (248526 bytes)
# │   │       │           └── DIR: rwmzdt (10176 bytes)
# │   │       │               └── FILE: hdb (10176 bytes)
# │   │       └── DIR: fgqbpcn (1408982 bytes)
# │   │           ├── FILE: dhzp (169227 bytes)
# │   │           ├── DIR: dwsgcrz (300751 bytes)
# │   │           │   └── FILE: fjlw.wtp (300751 bytes)
# │   │           ├── FILE: pjjln.ngc (140391 bytes)
# │   │           ├── FILE: ppmtvcj.ngb (162589 bytes)
# │   │           ├── FILE: rcgbjn.wfv (199626 bytes)
# │   │           ├── DIR: snrl (219131 bytes)
# │   │           │   ├── FILE: ccjp.jpw (16142 bytes)
# │   │           │   ├── FILE: cmbnljt.ljq (150389 bytes)
# │   │           │   └── FILE: gqggd.dwm (52600 bytes)
# │   │           └── DIR: vfnrs (217267 bytes)
# │   │               └── FILE: bwlpdfv.hzh (217267 bytes)
# │   └── DIR: vmdlwdj (1467519 bytes)
# │       ├── FILE: bcgjdpj.qcj (29199 bytes)
# │       ├── FILE: jjgrcd.cvf (172894 bytes)
# │       ├── DIR: ngpnmbqz (735834 bytes)
# │       │   ├── DIR: gnsm (476207 bytes)
# │       │   │   ├── DIR: rjzngs (344764 bytes)
# │       │   │   │   ├── DIR: dpfcw (181566 bytes)
# │       │   │   │   │   └── FILE: mgdjjd.pqg (181566 bytes)
# │       │   │   │   └── DIR: spmhrb (163198 bytes)
# │       │   │   │       └── FILE: hhcfpnmg.njm (163198 bytes)
# │       │   │   └── DIR: tvv (131443 bytes)
# │       │   │       └── FILE: hhcfpnmg.njm (131443 bytes)
# │       │   └── DIR: ntsgrm (259627 bytes)
# │       │       ├── FILE: dlz (246786 bytes)
# │       │       └── FILE: pzbgrn (12841 bytes)
# │       ├── FILE: ppmtvcj.bfr (296193 bytes)
# │       ├── DIR: tfvhhpn (196923 bytes)
# │       │   └── FILE: dhzp (196923 bytes)
# │       └── FILE: wqzst.wcj (36476 bytes)
# ├── DIR: pzg (262706 bytes)
# │   └── FILE: ppbqssj.hjj (262706 bytes)
# └── DIR: thfgwwsp (8389675 bytes)
#     ├── DIR: dsvc (22089 bytes)
#     │   └── FILE: dlz (22089 bytes)
#     ├── DIR: fbg (289639 bytes)
#     │   └── FILE: hhcfpnmg.njm (289639 bytes)
#     ├── DIR: flgmdj (293793 bytes)
#     │   └── FILE: fqrpf (293793 bytes)
#     ├── FILE: gwppndsl (516 bytes)
#     ├── DIR: mwl (6349458 bytes)
#     │   ├── FILE: dhzp (159673 bytes)
#     │   ├── DIR: ftthgr (1482938 bytes)
#     │   │   ├── DIR: ccrvnht (164437 bytes)
#     │   │   │   └── FILE: hdb (164437 bytes)
#     │   │   ├── FILE: ljltl.slv (170369 bytes)
#     │   │   ├── DIR: mwl (920513 bytes)
#     │   │   │   ├── DIR: cjsc (294891 bytes)
#     │   │   │   │   ├── FILE: hhcfpnmg.njm (91883 bytes)
#     │   │   │   │   └── FILE: nfmvr (203008 bytes)
#     │   │   │   ├── DIR: zcbnwhzd (187513 bytes)
#     │   │   │   │   └── DIR: mbtsvblj (187513 bytes)
#     │   │   │   │       └── FILE: ljpzpdbf (187513 bytes)
#     │   │   │   └── DIR: zwzb (438109 bytes)
#     │   │   │       ├── FILE: ljpzpdbf (138631 bytes)
#     │   │   │       └── DIR: sjngjp (299478 bytes)
#     │   │   │           ├── FILE: ccjp.ttc (52116 bytes)
#     │   │   │           ├── FILE: fptzbpp.sdm (157900 bytes)
#     │   │   │           └── FILE: hhcfpnmg.njm (89462 bytes)
#     │   │   ├── DIR: zqts (162402 bytes)
#     │   │   │   └── FILE: hdb (162402 bytes)
#     │   │   └── FILE: zvnhmqpz.cqb (65217 bytes)
#     │   ├── FILE: hhcfpnmg.njm (270973 bytes)
#     │   ├── DIR: jjrq (3402667 bytes)
#     │   │   ├── DIR: bffvw (964059 bytes)
#     │   │   │   ├── FILE: dqqtq.lnb (139679 bytes)
#     │   │   │   ├── DIR: mwl (495633 bytes)
#     │   │   │   │   ├── DIR: fdlmfjt (75969 bytes)
#     │   │   │   │   │   └── FILE: hdtbcsfc.vmz (75969 bytes)
#     │   │   │   │   ├── DIR: jms (297556 bytes)
#     │   │   │   │   │   └── FILE: hhcfpnmg.njm (297556 bytes)
#     │   │   │   │   └── FILE: nqwrj (122108 bytes)
#     │   │   │   ├── FILE: sjln.zgv (13310 bytes)
#     │   │   │   ├── FILE: srmghrt.ffl (243329 bytes)
#     │   │   │   └── FILE: ssm.tph (72108 bytes)
#     │   │   ├── DIR: czbwf (320541 bytes)
#     │   │   │   └── FILE: ccjp (320541 bytes)
#     │   │   ├── FILE: dlz (13447 bytes)
#     │   │   ├── DIR: gjh (450375 bytes)
#     │   │   │   ├── FILE: dhzp (164281 bytes)
#     │   │   │   └── FILE: vjs (286094 bytes)
#     │   │   └── DIR: hjs (1654245 bytes)
#     │   │       ├── DIR: cbdzvd (153733 bytes)
#     │   │       │   └── FILE: dhzp (153733 bytes)
#     │   │       ├── FILE: ccjp (41353 bytes)
#     │   │       ├── DIR: gbs (233469 bytes)
#     │   │       │   └── DIR: nfnb (233469 bytes)
#     │   │       │       └── DIR: hgm (233469 bytes)
#     │   │       │           └── FILE: ljpzpdbf (233469 bytes)
#     │   │       ├── FILE: hdb (114686 bytes)
#     │   │       ├── DIR: hmtpm (14247 bytes)
#     │   │       │   └── FILE: mwl (14247 bytes)
#     │   │       ├── FILE: ljpzpdbf (278709 bytes)
#     │   │       ├── DIR: ppmtvcj (439644 bytes)
#     │   │       │   ├── DIR: jcwhvcf (198254 bytes)
#     │   │       │   │   └── FILE: wddq.rgp (198254 bytes)
#     │   │       │   └── FILE: mwl (241390 bytes)
#     │   │       ├── FILE: zcmlbbbc.mpp (292308 bytes)
#     │   │       └── FILE: zttwct (86096 bytes)
#     │   ├── FILE: ljpzpdbf (279365 bytes)
#     │   ├── DIR: mglzfcq (633109 bytes)
#     │   │   ├── DIR: bsplglmj (75000 bytes)
#     │   │   │   └── DIR: zcbnwhzd (75000 bytes)
#     │   │   │       └── DIR: mqzqz (75000 bytes)
#     │   │   │           └── FILE: ppmtvcj (75000 bytes)
#     │   │   ├── FILE: fhflt.vgq (21700 bytes)
#     │   │   ├── FILE: lpmcbzrj (56724 bytes)
#     │   │   ├── FILE: qnbr (222733 bytes)
#     │   │   └── FILE: thvbqb.gtv (256952 bytes)
#     │   ├── FILE: pnz (101769 bytes)
#     │   └── FILE: rdl.wqf (18964 bytes)
#     ├── DIR: qfhsr (319974 bytes)
#     │   ├── FILE: gfv.cnw (249770 bytes)
#     │   └── FILE: qlvwhff.jhm (70204 bytes)
#     ├── DIR: tgj (243926 bytes)
#     │   └── FILE: mwl.bfv (243926 bytes)
#     ├── DIR: wdmzc (545409 bytes)
#     │   ├── FILE: hdb (19843 bytes)
#     │   ├── FILE: jbqf.str (264263 bytes)
#     │   └── FILE: qrvt.lbr (261303 bytes)
#     ├── FILE: zcbnwhzd (272804 bytes)
#     └── DIR: zrfmzrl (52067 bytes)
#         └── FILE: lnfgp.nhl (52067 bytes)

# %%
answer_1_nodes = anytree.search.findall(nodes_list[0], filter_=lambda node: node.node_size <= 100000 and node.node_type == "dir")

answer_1_value = sum(node.node_size for node in answer_1_nodes)

print(answer_1_value)
# Out:
# 1513699

# %%
total_disk_space = 70000000
used_disk_space = nodes_list[0].node_size
free_disk_space = total_disk_space - used_disk_space

print(free_disk_space)

required_update_space = 30000000
min_space_to_delete = required_update_space - free_disk_space

print(required_update_space)
print(min_space_to_delete)

def get_size(node:Node):
    return node.node_size

answer_2_nodes = anytree.search.findall(nodes_list[0], filter_=lambda node: node.node_size >= min_space_to_delete and node.node_size <= required_update_space and node.node_type == "dir")

# Answer is the lowest of these nodes.
print(answer_2_nodes)

# 7991939
# Out:
# 23123469
# 30000000
# 6876531
# (DIR: pntzm (29757629 bytes), DIR: mbtsvblj (27924493 bytes), DIR: csqcnmtc (9405481 bytes), DIR: mbtsvblj (7991939 bytes), DIR: zcrrtlh (14682970 bytes), DIR: dhsmmlt (13246500 bytes), DIR: wffbp (12324512 bytes), DIR: mbtsvblj (10264814 bytes), DIR: mbtsvblj (8113815 bytes), DIR: thfgwwsp (8389675 bytes))
